# %%
import matplotlib.pyplot as plt
import pandas as pd
filename='RMSD.csv'
df = pd.read_csv(filename, header=None)
df.columns=['Element', '313b2df8488dc2910ca3dc204b41eda8_mutated_3']
# print(df['313b2df8488dc2910ca3dc204b41eda8_mutated_3'])
# print(df.)
plt.bar(df['Element'], df['313b2df8488dc2910ca3dc204b41eda8_mutated_3'])
plt.ylabel('RMSD ($\AA$/atom)')
plt.title("RMSD between Original and re-Optimized")
# Out:
# <>:9: SyntaxWarning: invalid escape sequence '\A'
# <>:9: SyntaxWarning: invalid escape sequence '\A'
# /tmp/ipykernel_256614/2511290393.py:9: SyntaxWarning: invalid escape sequence '\A'
#   plt.ylabel('RMSD ($\AA$/atom)')
# Text(0.5, 1.0, 'RMSD between Original and re-Optimized')
